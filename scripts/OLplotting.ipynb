# %%
import pandas as pd
import numpy as np


file = pd.read_csv('data_flippedcopy.csv')
object1 = np.where((file.action == 'object1_start') | (file.action == 'object1_stop'))
object1

object2 = np.where((file.action == 'object2_start') | (file.action == 'object2_stop'))
object2

filenames = ['Y:/laura_berkowitz/app_ps1_ephys/data/hpc04/hpc04_day06_220217_085558/day06_OLbase_hpc04.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc04/hpc04_day06_220217_085558/day06_OLtest_hpc04.avi',
             'D:/app_ps1/data/hpc04/hpc04_day09_220221_094101/hpc04_Base_day09-02212022113925-0000_h264.avi',
             'D:/app_ps1/data/hpc04/hpc04_day09_220221_094101/hpc04_test_day09-02212022140222-0000_h264.avi',
             'D:/app_ps1/data/hpc04/hpc04_day15_220301_094823/hpc04_OLbase_day15-03012022123120-0000_h264.avi',
             'D:/app_ps1/data/hpc04/hpc04_day15_220301_094823/hpc04_OLtest_day15-03012022152140-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hpc05_day17_220324_085048/hpc05_OLbase_day17-03242022122559-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hpc05_day17_220324_085048/hpc05_OLtest_day17-03242022151150-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day17_220324_085048/hpc06_OLbase_day17-03242022110709-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day17_220324_085048/hpc06_OLtest_day17-03242022142548-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day23_220401_102719/hpc06_BaseOL_day23-04012022134609-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day23_220401_102719/hpc06_TestOL_day23-04012022164229-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day27_220405_103420/hpc06_OLbase_day27-04052022132251-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day27_220405_103420/hpc06_OLtest_day27-04052022162011-0000_h264.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_day25_220524_093304/hpc07_OFbase2_dayxx-05242022121709.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_day25_220524_093304/hpc07_OLtest2_dayxx-05242022163255.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/to_split/june14_220614_100545/hpc10_OFbase_dayxx-06142022121605.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/to_split/june14_220614_100545/hpc10-OFtest_dayxx-06142022160504.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc10_OFbase_dayxx-06102022123814.avi',
             'Y:/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc10_OFtest_dayxx-06102022162852.avi']


def intersection(list1, list2):
    return list(set(list1) & set(list2))

intersection(filenames, file.file)

idxtochange = []

for i in filenames:
    idxtochange = np.append(idxtochange, np.where((file.file == i)))

for i in idxtochange:
    if file.action[i] == 'object1_start':
        file.action[i] = 'object2_start'
    elif file.action[i] == 'object1_stop':
        file.action[i] = 'object2_stop'
    elif file.action[i] == 'object2_start':
        file.action[i] = 'object1_start'
    elif file.action[i] == 'object2_stop':
        file.action[i] = 'object1_stop'
        
len(sorted(intersection(filenames, file.file)))
# Out:
# <ipython-input-92-3775f6af6207>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file.action[i] = 'object2_start'
# <ipython-input-92-3775f6af6207>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file.action[i] = 'object2_stop'
# <ipython-input-92-3775f6af6207>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file.action[i] = 'object1_start'
# <ipython-input-92-3775f6af6207>:52: SettingWithCopyWarning:
# ...

# %%
file = file.dropna()
file.to_csv('flippedcopy.csv', index=False)
set(file.file)
# Out:
# {'//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_OLbase_dayxx-07122022134200.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc10/hpc10_OLbase_dayxx-07122022125200.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day09_220221_094101/hpc04_Base_day09-02212022113925-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day09_220221_094101/hpc04_test_day09-02212022140222-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day12_220225_115348/hpc04_OLbase_day11-02252022141631-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day12_220225_115348/hpc04_OLtest_day11-02252022172652-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day15_220301_094823/hpc04_OLbase_day15-03012022123120-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day15_220301_094823/hpc04_OLtest_day15-03012022152140-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc04/hpc04_day06_220217_085558/day06_OLbase_hpc04.avi',
# ...

# %%
set(file.file)
# Out:
# {'//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_OLbase_dayxx-07122022134200.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc10/hpc10_OLbase_dayxx-07122022125200.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day09_220221_094101/hpc04_Base_day09-02212022113925-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day09_220221_094101/hpc04_test_day09-02212022140222-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day12_220225_115348/hpc04_OLbase_day11-02252022141631-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day12_220225_115348/hpc04_OLtest_day11-02252022172652-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day15_220301_094823/hpc04_OLbase_day15-03012022123120-0000_h264.avi',
#  'D:/app_ps1/data/hpc04/hpc04_day15_220301_094823/hpc04_OLtest_day15-03012022152140-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc04/hpc04_day06_220217_085558/day06_OLbase_hpc04.avi',
# ...

# %%
newfile = pd.read_csv('flippedcopy_final.csv')
newfile.action

time1 = 0
time2 = 0



for i in range(1, len(newfile.action)):
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1]- newfile.frame[i])/60        
time1
time2  
#DI = (Moved object time - unmoved)/ total object explore time

len(newfile)
len(file)
# Out:
# 2110

# %%
hpc04_day06_base = np.where(newfile.file == filenames[1])
hpc04_day06_test = np.where(newfile.file == filenames[2])

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc04_day06_base[0]:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc04_day06_test[0]:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)
# Out:
# 110.79999999999998 102.63333333333334 21.299999999999997 6.25

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = {'baseline':DIbase, 'test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC04 Day 6")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# <BarContainer object of 2 artists>

# %%
hpc04_day09_base = np.where(newfile.file == filenames[3])
hpc04_day09_test = np.where(newfile.file == filenames[4])

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc04_day09_base[0]:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc04_day09_test[0]:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'baseline':DIbase, 'test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC04 Day 9")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 56.78333333333334 44.78333333333333 32.3 58.61666666666668
# <BarContainer object of 2 artists>

# %%
hpc04_day12_base = np.where(newfile.file == list(set(file.file))[3])
hpc04_day12_test = np.where(newfile.file == list(set(file.file))[4])

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc04_day12_base[0]:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc04_day12_test[0]:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'baseline':DIbase, 'test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC04 Day 12")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 23.033333333333335 29.033333333333342 24.866666666666664 27.383333333333336
# <BarContainer object of 2 artists>

# %%
hpc04_day15_base = np.where(newfile.file == filenames[5])
hpc04_day15_test = np.where(newfile.file == filenames[6])

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc04_day15_base[0]:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc04_day15_test[0]:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'baseline':DIbase, 'test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC04 Day 15")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 28.149999999999995 39.833333333333336 0 2.95
# <BarContainer object of 2 artists>

# %%
hpc04_base = np.concatenate((hpc04_day06_base, hpc04_day09_base, hpc04_day12_base, hpc04_day15_base), axis = None)
hpc04_base
hpc04_test = np.concatenate((hpc04_day06_test, hpc04_day09_test, hpc04_day12_test, hpc04_day15_test), axis = None)
hpc04_test

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc04_base:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc04_test:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'Baseline':DIbase, 'Test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC04")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 218.76666666666668 216.28333333333322 78.46666666666667 95.20000000000003
# <BarContainer object of 2 artists>

# %%
allnewfiles = sorted(list(set(newfile.file)))

def index_containing_substring(the_list, substring):
    index = []
    for i, s in enumerate(the_list):
        if substring in s:
              index = np.append(index, i)
    return(index)

hpc06_idx = list(index_containing_substring(allnewfiles, 'hpc06'))
hpc07_idx = list(index_containing_substring(allnewfiles, 'hpc07'))
hpc09_idx = list(index_containing_substring(allnewfiles, 'hpc09'))
hpc10_idx = list(index_containing_substring(allnewfiles, 'hpc10'))

hpc06_names = []
hpc07_names = []
hpc09_names = []
hpc10_names = []

for i in range(len(hpc06_idx)):
    hpc06_names.append(allnewfiles[int(hpc06_idx[i])])

for i in range(len(hpc07_idx)):
    hpc07_names.append(allnewfiles[int(hpc07_idx[i])])
    
for i in range(len(hpc06_idx)):
    hpc09_names.append(allnewfiles[int(hpc09_idx[i])])
    
for i in range(len(hpc06_idx)):
    hpc10_names.append(allnewfiles[int(hpc10_idx[i])])
    
indexes = [0, 1, 2, 3, 6, 7, 8, 9]
hpc07_names = [hpc07_names[x] for x in indexes]

indexes = [2, 3, 4, 5]
hpc10_names = [hpc10_names[x] for x in indexes]

# %%
hpc06_names
# Out:
# ['Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day14_220320_102335/hpc06_OLbase_day14-03202022131854-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day14_220320_102335/hpc06_OLtest_day14-03202022164244-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day17_220324_085048/hpc06_OLbase_day17-03242022110709-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day17_220324_085048/hpc06_OLtest_day17-03242022142548-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day23_220401_102719/hpc06_BaseOL_day23-04012022134609-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day23_220401_102719/hpc06_TestOL_day23-04012022164229-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day27_220405_103420/hpc06_OLbase_day27-04052022132251-0000_h264.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc06/hpc06_day27_220405_103420/hpc06_OLtest_day27-04052022162011-0000_h264.avi']

# %%
hpc06_base = np.where((newfile.file == hpc06_names[0]) |
                      (newfile.file == hpc06_names[2]) |
                      (newfile.file == hpc06_names[4]) |
                      (newfile.file == hpc06_names[6]))[0]
hpc06_test = np.where((newfile.file == hpc06_names[1]) | 
                      (newfile.file == hpc06_names[3]) |
                      (newfile.file == hpc06_names[5]) |
                      (newfile.file == hpc06_names[7]))[0]

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc06_base:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc06_test:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'Baseline':DIbase, 'Test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC06")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 215.84999999999994 85.35 167.89999999999995 102.43333333333332
# <BarContainer object of 2 artists>

# %%
hpc07_names
# Out:
# ['//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_day35_220606_085359/hpc07_OFtest_dayxx-06062022154000.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_day35_220606_085359/hpc07_OLbase_dayxx-06062022115459.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc07_OFbase_dayxx-06102022133451.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc07_OFtest_dayxx-06102022171747.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_day10_220503_082347/hpc07_OLbase_day10-05032022104417.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_day10_220503_082347/hpc07_OLtest_day10-05032022142430.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/hpc07/hpc07_day25_220524_093304/hpc07_OFbase2_dayxx-05242022121709.avi',
# ...

# %%
hpc07_base = np.where((newfile.file == hpc07_names[1]) |
                      (newfile.file == hpc07_names[2]) |
                      (newfile.file == hpc07_names[4]) |
                      (newfile.file == hpc07_names[6]))[0]
hpc07_test = np.where((newfile.file == hpc07_names[0]) | 
                      (newfile.file == hpc07_names[3]) |
                      (newfile.file == hpc07_names[5]) |
                      (newfile.file == hpc07_names[7]))[0]

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc07_base:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc07_test:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'Baseline':DIbase, 'Test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC07")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 199.5166666666665 113.61666666666666 109.5833333333333 135.61666666666667
# <BarContainer object of 2 artists>

# %%
hpc09_names
# Out:
# ['//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc09/hpc09_day19_220524_093304/hpc09_OFbase1_dayxx-05242022130207.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/hpc09/hpc09_day19_220524_093304/hpc09_OLtest1_dayxx-05242022165621.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc09_OFbase_dayxx-06102022141701.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc09_OFtest_dayxx-06102022180703.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/to_split/hpc10_hpc07_hpc09_220528_1105/hpc09_OLbase_dayxx-05282022143413.avi',
#  '//10.253.5.16/sn data server 3/laura_berkowitz/app_ps1_ephys/data/to_split/hpc10_hpc07_hpc09_220528_1105/hpc09_OLtest_dayxx-05282022183004.avi',
# ...

# %%
hpc09_base = np.where((newfile.file == hpc09_names[0]) |
                      (newfile.file == hpc09_names[2]) |
                      (newfile.file == hpc09_names[4]) |
                      (newfile.file == hpc09_names[6]))[0]
hpc09_test = np.where((newfile.file == hpc09_names[1]) | 
                      (newfile.file == hpc09_names[3]) |
                      (newfile.file == hpc09_names[5]) |
                      (newfile.file == hpc09_names[7]))[0]

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc09_base:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc09_test:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'Baseline':DIbase, 'Test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("HPC09")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 209.38333333333327 177.61666666666667 83.88333333333334 155.21666666666667
# <BarContainer object of 2 artists>

# %%
hpc10_names
# Out:
# ['Y:/laura_berkowitz/app_ps1_ephys/data/hpc10/hpc10_day44_220622_085917/hpc10_OFtest_dayxx-06222022162447.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc10_OFbase_dayxx-06102022123814.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/to_split/day00_day02_day04_220610_101437/hpc10_OFtest_dayxx-06102022162852.avi',
#  'Y:/laura_berkowitz/app_ps1_ephys/data/to_split/hpc10_OFbase_dayxx-06222022123304.avi']

# %%
hpc10_base = np.where((newfile.file == hpc10_names[1]) |
                      (newfile.file == hpc10_names[3]))[0]
hpc10_test = np.where((newfile.file == hpc10_names[0]) | 
                      (newfile.file == hpc10_names[2]))[0]

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in hpc10_base:
    if newfile.action[i] == 'object1_start':
        time1 = time1 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time2 = time2 + (newfile.frame[i+1] - newfile.frame[i])/60

for i in hpc10_test:
    if newfile.action[i] == 'object1_start':
        time3 = time3 + (newfile.frame[i+1] - newfile.frame[i])/60
    elif newfile.action[i] == 'object2_start':
        time4 = time4 + (newfile.frame[i+1] - newfile.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

data = {'Baseline':DIbase, 'Test':DItest}
condition = list(data.keys())
DI = list(data.values())

plt.ylabel("Discrimination Index")
plt.title("hpc10")

plt.bar(condition, DI, color ='maroon',
        width = 0.4)
# Out:
# 62.31666666666667 40.883333333333326 37.23333333333333 66.26666666666667
# <BarContainer object of 2 artists>

# %%
object_location = pd.read_csv('flippedcopy_final.csv')
metadata = pd.read_csv('object_location_metadata.csv')
object_location["vidname"] = [
    file.split("/")[-1].split(".")[0] for file in object_location.file]
object_location["genotype"] = "WT"
object_location.loc[object_location.vidname.str.contains(
    "hpc05"), "genotype"] = "TG"
object_location.loc[object_location.vidname.str.contains(
    "hpc09"), "genotype"] = "TG"
object_location.loc[object_location.vidname.str.contains(
    "hpc10"), "genotype"] = "TG"

object_location["subid"] = "hpc04"
object_location.loc[object_location.vidname.str.contains(
    "hpc05"), "subid"] = "hpc05"
object_location.loc[object_location.vidname.str.contains(
    "hpc06"), "subid"] = "hpc06"
object_location.loc[object_location.vidname.str.contains(
    "hpc07"), "subid"] = "hpc07"
object_location.loc[object_location.vidname.str.contains(
    "hpc09"), "subid"] = "hpc09"
object_location.loc[object_location.vidname.str.contains(
    "hpc10"), "subid"] = "hpc10"

object_location["condition"] = "baseline"
object_location.loc[object_location.vidname.str.contains("test", case = False), "condition"] = "test"

object_location["treatment"] = "none"
object_location["paradigm"] = "baseline"
object_location["visit"] = 0
for i in range(len(metadata)):
    object_location.treatment.loc[object_location.vidname == metadata.vidname[i]] = metadata.treatment[i]
    object_location.paradigm.loc[object_location.vidname == metadata.vidname[i]] = metadata.condition[i]

for i in range(len(metadata)):
    file_idx = object_location.vidname == metadata.vidname[i]
    temp_df = object_location[file_idx]
    temp_df["visit"] = (
        np.arange(np.sum(temp_df.action.str.contains("start")))
        .astype(str)
        .repeat(2))
    object_location.visit.loc[
        object_location.vidname == metadata.vidname[i]] = temp_df.visit.loc[temp_df.vidname == metadata.vidname[i]]

object_location.to_csv('object_location_final.csv', index=False)
# Out:
# <ipython-input-98-27a2937f00b2>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df["visit"] = (

# %%
#check for data entry errors
for i in range(len(metadata)):
    if np.sum(object_location.action.loc[
        object_location.vidname == metadata.vidname[i]].str.contains("start")) != len(object_location.action.loc[
        object_location.vidname == metadata.vidname[i]].str.contains("start"))/2:
        print(metadata.vidname[i])

# %%
object_location
# Out:
#                                                    file  frame         action  \
# 0     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  54591  object1_start
# 1     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  54655   object1_stop
# 2     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  66499  object1_start
# 3     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  66568   object1_stop
# 4     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  66467  object2_start
# ...                                                 ...    ...            ...
# 3591  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  73914   object2_stop
# 3592  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  74192  object2_start
# 3593  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  74303   object2_stop
# 3594  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  76972  object2_start
# 3595  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  77093   object2_stop
#
# ...

# %%
newOL = object_location.pivot_table(
    object_location,
    index=[
        "file",
        "subid",
        "vidname",
        "genotype",
        "condition",
        "treatment",
        "paradigm",
        "visit"
    ],
    columns=["action"],
).reset_index()
newOL["object1_explore"] = (
    newOL.frame.object1_stop - newOL.frame.object1_start
) / 60
newOL["object2_explore"] = (
    newOL.frame.object2_stop - newOL.frame.object2_start
) / 60

metadata["paradigm"] = metadata.condition
metadata["condition"] = "baseline"
metadata.loc[metadata.vidname.str.contains("test", case = False), "condition"] = "test"
metadata["DI"] = np.nan

for i in range(len(metadata)):
    object1sum = np.sum(newOL.object1_explore.loc[newOL.vidname == metadata.vidname[i]])
    object2sum = np.sum(newOL.object2_explore.loc[newOL.vidname == metadata.vidname[i]])
    metadata.DI[i] = (object2sum - object1sum) / (object2sum + object1sum)

newOL.to_csv('pivot.csv', index = False)
metadata.to_csv('meta.csv', index = False)
# Out:
# <ipython-input-101-8a59d90f181f>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata.DI[i] = (object2sum - object1sum) / (object2sum + object1sum)
# <ipython-input-101-8a59d90f181f>:30: RuntimeWarning: invalid value encountered in double_scalars
#   metadata.DI[i] = (object2sum - object1sum) / (object2sum + object1sum)

# %%
newOL
# Out:
#                                                      file  subid  \
# action
# 0       //10.253.5.16/sn data server 3/laura_berkowitz...  hpc07
# 1       //10.253.5.16/sn data server 3/laura_berkowitz...  hpc07
# 2       //10.253.5.16/sn data server 3/laura_berkowitz...  hpc07
# 3       //10.253.5.16/sn data server 3/laura_berkowitz...  hpc07
# 4       //10.253.5.16/sn data server 3/laura_berkowitz...  hpc07
# ...                                                   ...    ...
# 1700    Y:/laura_berkowitz/app_ps1_ephys/data/to_split...  hpc10
# 1701    Y:/laura_berkowitz/app_ps1_ephys/data/to_split...  hpc10
# 1702    Y:/laura_berkowitz/app_ps1_ephys/data/to_split...  hpc10
# 1703    Y:/laura_berkowitz/app_ps1_ephys/data/to_split...  hpc10
# 1704    Y:/laura_berkowitz/app_ps1_ephys/data/to_split...  hpc10
#
#                                   vidname genotype condition treatment  \
# action
# 0       hpc07_OFtest_dayxx-06062022154000       WT      test      ly6g
# ...

# %%
overall = pd.DataFrame({"subid": 
                        ["hpc04", "hpc04", 
                         "hpc06", "hpc06", "hpc07", "hpc07",
                         "hpc09", "hpc09", "hpc10", "hpc10"],
                        "condition":
                        ["base", "test", "base", "test",
                         "base", "test", "base", "test",
                         "base", "test", "base", "test"]})

subids = sorted(set(newOL.subid))
overall["DI"] = np.nan

for i in range(0, len(overall), 2):
    baseidx = np.where((newOL.condition == 'baseline') & (newOL.subid == overall.subid[i]))
    testidx = np.where((newOL.condition == 'test') & (newOL.subid == overall.subid[i]))
    object1base = np.sum(newOL.object1_explore.loc[baseidx])
    object2base = np.sum(newOL.object2_explore.loc[baseidx])
    object1test = np.sum(newOL.object1_explore.loc[testidx])
    object2test = np.sum(newOL.object2_explore.loc[testidx])
    overall.DI.loc[i] = (object2base - object1base) / (object2base + object1base)
    overall.DI.loc[i+1] = (object2test - object1test) / (object2test + object1test)
    
overall
metadata
# Out:
# C:\Users\ryan_\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#     subid genotype                                      vidname  \
# 0   hpc04       WT                           day06_OLbase_hpc04
# 1   hpc04       WT                           day06_OLtest_hpc04
# 2   hpc04       WT    hpc04_Base_day09-02212022113925-0000_h264
# 3   hpc04       WT    hpc04_test_day09-02212022140222-0000_h264
# 4   hpc04       WT  hpc04_OLbase_day11-02252022141631-0000_h264
# 5   hpc04       WT  hpc04_OLtest_day11-02252022172652-0000_h264
# 6   hpc04       WT  hpc04_OLbase_day15-03012022123120-0000_h264
# 7   hpc04       WT  hpc04_OLtest_day15-03012022152140-0000_h264
# ...

# %%
object_location
# Out:
#                                                    file  frame         action  \
# 0     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  54591  object1_start
# 1     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  54655   object1_stop
# 2     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  66499  object1_start
# 3     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  66568   object1_stop
# 4     Y:/laura_berkowitz/app_ps1_ephys/data/hpc05/hp...  66467  object2_start
# ...                                                 ...    ...            ...
# 3591  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  73914   object2_stop
# 3592  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  74192  object2_start
# 3593  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  74303   object2_stop
# 3594  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  76972  object2_start
# 3595  Y:/laura_berkowitz/app_ps1_ephys/data/hpc09/hp...  77093   object2_stop
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")




ax = sns.scatterplot(x= "condition", y = "DI", hue = "subid", data = overall)
ax1 = sns.lineplot(x = "condition", y = "DI", hue = "subid", legend = False, data = overall)

# %%
sns.set_style("darkgrid")
WTmeta = metadata.loc[metadata.genotype.str.contains("WT")].reset_index()
ax2 = sns.scatterplot(x = "condition", y = "DI", hue= "subid", data = WTmeta).set(title = 'WT')

def getlines(x, y, color):
    for j in range(0, len(x), 2):
        plt.plot(x[j:j+2], y[j:j+2], color = color)

x = WTmeta.condition.loc[np.where(WTmeta.subid.str.contains('hpc04'))]
y = WTmeta.DI.loc[np.where(WTmeta.subid.str.contains('hpc04'))]

getlines(x, y, 'blue')

x = WTmeta.condition.loc[np.where(WTmeta.subid.str.contains('hpc06'))]
y = WTmeta.DI.loc[np.where(WTmeta.subid.str.contains('hpc06'))]

getlines(x, y, 'orange')

x = WTmeta.condition.loc[np.where(WTmeta.subid.str.contains('hpc07'))]
y = WTmeta.DI.loc[np.where(WTmeta.subid.str.contains('hpc07'))]

getlines(x, y, 'green')

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-2f755f117ac9> in <module>
# ----> 1 x[0]
#
# IndexError: list index out of range

# %%
TGmeta = metadata.loc[metadata.genotype.str.contains("TG")].reset_index()
ax4 = sns.scatterplot(x = "condition", y = "DI", hue= "subid", data = TGmeta).set(title = 'TG')

x = TGmeta.condition.loc[np.where(TGmeta.subid.str.contains('hpc09'))]
y = TGmeta.DI.loc[np.where(TGmeta.subid.str.contains('hpc09'))]

getlines(x, y, 'orange')

x = TGmeta.condition.loc[np.where(TGmeta.subid.str.contains('hpc10'))]
y = TGmeta.DI.loc[np.where(TGmeta.subid.str.contains('hpc10'))]

getlines(x, y, 'green')

# %%
ax5 = sns.scatterplot(x = "condition", y = "DI", hue= "treatment", data = metadata)

x = metadata.condition.loc[np.where(metadata.treatment.str.contains('isotype'))]
y = metadata.DI.loc[np.where(metadata.treatment.str.contains('isotype'))]
getlines(x, y, 'blue')

x = metadata.condition.loc[np.where(metadata.treatment.str.contains('ly6g'))]
y = metadata.DI.loc[np.where(metadata.treatment.str.contains('ly6g'))]
getlines(x, y, 'orange')

x = metadata.condition.loc[np.where(metadata.treatment.str.contains('none'))]
y = metadata.DI.loc[np.where(metadata.treatment.str.contains('none'))]
getlines(x, y, 'green')

# %%
ax6 = sns.scatterplot(x = "condition", y = "DI", hue= "objects", data = metadata)
x = metadata.condition.loc[np.where(metadata.objects.str.contains('salt_shakers'))]
y = metadata.DI.loc[np.where(metadata.objects.str.contains('salt_shakers'))]
getlines(x, y, 'blue')
x = metadata.condition.loc[np.where(metadata.objects.str.contains('woman'))]
y = metadata.DI.loc[np.where(metadata.objects.str.contains('woman'))]
getlines(x, y, 'orange')
plt.plot(metadata.condition.loc[np.where(metadata.objects.str.contains('tiana'))],
         metadata.DI.loc[np.where(metadata.objects.str.contains('tiana'))], color = 'green')
getlines(x, y, 'green')
plt.plot(metadata.condition.loc[np.where(metadata.objects.str.contains('ornament'))],
         metadata.DI.loc[np.where(metadata.objects.str.contains('ornament'))], color = 'red')
getlines(x, y, 'red')
plt.plot(metadata.condition.loc[np.where(metadata.objects.str.contains('mary'))],
         metadata.DI.loc[np.where(metadata.objects.str.contains('mary'))], color = 'purple')
getlines(x, y, 'purple')
plt.plot(metadata.condition.loc[np.where(metadata.objects.str.contains('marge'))],
         metadata.DI.loc[np.where(metadata.objects.str.contains('marge'))], color = 'brown')
getlines(x, y, 'brown')
plt.plot(metadata.condition.loc[np.where(metadata.objects.str.contains('wiffle'))],
         metadata.DI.loc[np.where(metadata.objects.str.contains('wiffle'))], color = 'pink')
getlines(x, y, 'pink')
plt.plot(metadata.condition.loc[np.where(metadata.objects.str.contains('cups'))],
         metadata.DI.loc[np.where(metadata.objects.str.contains('cups'))], color = 'grey')
getlines(x, y, 'grey')
plt.plot(metadata.condition.loc[np.where(metadata.objects.str.contains('ceramic'))],
         metadata.DI.loc[np.where(metadata.objects.str.contains('ceramic'))], color = 'yellow')
getlines(x, y, 'yellow')

# %%
ax7 = sns.scatterplot(x = "condition", y = "DI", hue= "paradigm", data = metadata)

x = metadata.condition.loc[np.where(metadata.paradigm.str.contains('encoding'))]
y = metadata.DI.loc[np.where(metadata.paradigm.str.contains('encoding'))]
getlines(x, y, 'blue')

x = metadata.condition.loc[np.where(metadata.paradigm.str.contains('consolidation'))]
y = metadata.DI.loc[np.where(metadata.paradigm.str.contains('consolidation'))]
getlines(x, y, 'orange')

x = metadata.condition.loc[np.where(metadata.paradigm.str.contains('baseline'))]
y = metadata.DI.loc[np.where(metadata.paradigm.str.contains('baseline'))]
getlines(x, y, 'green')

# %%
#throw out hpc05, did not explore objects sufficiently

# %%
import pandas as pd

group9Abase = pd.read_csv("group9_A_base.csv")
group9Atest = pd.read_csv("group9_A_test.csv")



time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in range(0, len(group9Abase)):
    if group9Abase.action[i] == 'object1_start':
        time1 = time1 + (group9Abase.frame[i+1] - group9Abase.frame[i])/60
    elif group9Abase.action[i] == 'object2_start':
        time2 = time2 + (group9Abase.frame[i+1] - group9Abase.frame[i])/60

for i in range(0, len(group9Atest)):
    if group9Atest.action[i] == 'object1_start':
        time3 = time3 + (group9Atest.frame[i+1] - group9Atest.frame[i])/60
    elif group9Atest.action[i] == 'object2_start':
        time4 = time4 + (group9Atest.frame[i+1] - group9Atest.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

print(DIbase, DItest)
# Out:
# 99.49999999999999 81.21666666666668 15.75 60.64999999999999
# -0.10117126256571043 0.587696335078534

# %%
group9Bbase = pd.read_csv("group9_B_OLbase-07152022161700.csv")
group9Btest = pd.read_csv("group9_B_OLtest-07152022172009.csv")



time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in range(0, len(group9Bbase)):
    if group9Bbase.action[i] == 'object1_start':
        time1 = time1 + (group9Bbase.frame[i+2] - group9Bbase.frame[i])/60
    elif group9Bbase.action[i] == 'object2_start':
        time2 = time2 + (group9Bbase.frame[i+2] - group9Bbase.frame[i])/60

for i in range(0, len(group9Btest)):
    if group9Btest.action[i] == 'object1_start':
        time3 = time3 + (group9Btest.frame[i+2] - group9Btest.frame[i])/60
    elif group9Btest.action[i] == 'object2_start':
        time4 = time4 + (group9Btest.frame[i+2] - group9Btest.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

print(DIbase, DItest)
# Out:
# 31.516666666666666 18.849999999999998 9.850000000000001 11.666666666666666
# -0.25148908007941767 0.0844306738962044

# %% [raw]
# group9Abase

# %%
group9Bbase = pd.read_csv("group8_B_OLbase-07152022160150.csv")
group9Btest = pd.read_csv("group8_B_OLtest-07152022171004.csv")



time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in range(0, len(group9Bbase)):
    if group9Bbase.action[i] == 'object1_start':
        time1 = time1 + (group9Bbase.frame[i+2] - group9Bbase.frame[i])/60
    elif group9Bbase.action[i] == 'object2_start':
        time2 = time2 + (group9Bbase.frame[i+2] - group9Bbase.frame[i])/60

for i in range(0, len(group9Btest)):
    if group9Btest.action[i] == 'object1_start':
        time3 = time3 + (group9Btest.frame[i+2] - group9Btest.frame[i])/60
    elif group9Btest.action[i] == 'object2_start':
        time4 = time4 + (group9Btest.frame[i+2] - group9Btest.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

print(DIbase, DItest)
# Out:
# 65.43333333333334 60.833333333333314 25.649999999999995 41.716666666666676
# -0.03643083421330536 0.23849579416130645

# %%
group9Bbase = pd.read_csv("group8_A_OLbase-07152022160150.csv")
group9Btest = pd.read_csv("group8_A_OLtest-07152022171004.csv")



time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in range(0, len(group9Bbase)):
    if group9Bbase.action[i] == 'object1_start':
        time1 = time1 + (group9Bbase.frame[i+2] - group9Bbase.frame[i])/60
    elif group9Bbase.action[i] == 'object2_start':
        time2 = time2 + (group9Bbase.frame[i+2] - group9Bbase.frame[i])/60

for i in range(0, len(group9Btest)):
    if group9Btest.action[i] == 'object1_start':
        time3 = time3 + (group9Btest.frame[i+2] - group9Btest.frame[i])/60
    elif group9Btest.action[i] == 'object2_start':
        time4 = time4 + (group9Btest.frame[i+2] - group9Btest.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

print(DIbase, DItest)
# Out:
# 21.333333333333332 16.983333333333334 22.1 90.28333333333333
# -0.11352762070465415 0.6067032478125464

# %%
def even(x):
    alleven = True
    mistakeloc = []
    for i in range(0, len(x)):
        if x[i] % 2 != 0:
            alleven = False
            mistakeloc.append(x[i])
    if alleven == False:
        return alleven, mistakeloc
    else:
        return alleven, 'No issues'

def odd(x):
    allodd = True
    mistakeloc = []
    for i in range(0, len(x)):
        if x[i] % 2 != 1:
            allodd = False
            mistakeloc.append(x[i])
    if allodd == False:
        print(mistakeloc)
        return allodd, mistakeloc
    else:
        return allodd, 'No issues'
    

base = pd.read_csv(basevids[0])
x = np.where(base.action.str.contains('start'))[0]
y = np.where(base.action.str.contains('stop'))[0]

x[4] = 9




#def troubleshoot(file):
    #df = pd.read_csv(file)
    #x = np.where(df.action.str.contains('start'))[0]
    #x[4] = 9
    
    #if even(x) != True:
        #return print(file, even(x))
    #else:
        #return('No problems')
    
#troubleshoot(basevids[0])

# %%
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

folder = 'cohort2_scoring'

def graphdata(folder):
    
    #initialize df
    overall = pd.DataFrame()
    subid = []; condition = []; DR = [];
    
    #pull files from folder
    directory = folder
    sheets = []
    for filename in os.scandir(directory):
        if filename.is_file():
            sheets.append(filename.path)

    basesheets = [s for s in sheets if 'base' in s]
    basesheets.sort()
    testsheets = [s for s in sheets if 'test' in s]
    testsheets.sort()

    #check for correct numbers of files
    if len(basesheets) != len(testsheets):
        print('Error: Unequal number of base and test files')
    
    for i in range(0, len(basesheets)):
        #make data easier to read
        base = pd.read_csv(basesheets[i])
        base = base.dropna()
        test = pd.read_csv(testsheets[i])
        test = test.dropna()
        
        #check for data entry mistakes in baseline files
        base_starts = np.where(base.action.str.contains('start'))[0]
        test_starts = np.where(test.action.str.contains('start'))[0]
        base_stops = np.where(base.action.str.contains('stop'))[0]
        test_stops = np.where(test.action.str.contains('stop'))[0]

        if even(base_starts)[0] == False:
            print('File: ', basesheets[i], '. Error(s) at ', even(base_starts)[1])
        if even(test_starts)[0] == False:
            print('File: ', testsheets[i], '. Error(s) at ', even(test_starts)[1])

        if odd(base_stops)[0] == False:
            print('File: ', basesheets[i], '. Error(s) at ', odd(base_stops)[1])
        if odd(test_stops)[0] == False:
            print('File: ', testsheets[i], '. Error(s) at ', odd(test_stops)[1])

        if len(base_starts) != len(base_stops):
            print('Error: unequal number of starts and stop in ', basesheets[i])
        if len(test_starts) != len(test_stops):
            print('Error: unequal number of starts and stop in ', testsheets[i])

        t1 = 0; t2 = 0; t3 = 0; t4 = 0

        for j in range(0, len(base)):
            if base.action[j] == 'object1_start':
                t1 = t1 + (base.frame[j+1] - base.frame[j])/60
            elif base.action[j] == 'object2_start':
                t2 = t2 + (base.frame[j+1] - base.frame[j])/60
        for j in range(0, len(test)):
            if test.action[j] == 'object1_start':
                t3 = t3 + (test.frame[j+1] - test.frame[j])/60
            elif test.action[j] == 'object2_start':
                t4 = t4 + (test.frame[j+1] - test.frame[j])/60

        DRbase = (t2 - t1)/(t2 + t1)
        DRtest = (t4 - t3)/(t4 + t3)

        subid.append(basesheets[i][16:24]); subid.append(basesheets[i][16:24])
        condition.append('base'); condition.append('test')
        DR.append(DRbase); DR.append(DRtest)
    overall['subid'] = subid
    overall['condition'] = condition
    overall['DR'] = DR
    sns.set_style("darkgrid")
    ax = sns.scatterplot(x= "condition", y = "DR", hue = "subid", data = overall).set(title = 'Object Location DR Comparison')
    ax1 = sns.lineplot(x = "condition", y = "DR", hue = "subid", legend = False, data = overall)
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    return ax, ax1

graphdata(folder)
# Out:
# ([Text(0.5, 1.0, 'Object Location DR Comparison')],
#  <matplotlib.axes._subplots.AxesSubplot at 0x182957fc730>)

# %%
import os
import numpy as np

folder = 'cohort2_scoring'

def graphdata(folder):
    #initialize data frame and columns that will later be concatenated
    overall = pd.DataFrame()
    subid = []; condition = []; DR = [];
    directory = folder
    sheets = []
    for filename in os.scandir(directory):
        if filename.is_file():
            sheets.append(filename.path)

    basesheets = [s for s in sheets if 'base' in s]
    basesheets.sort()
    testsheets = [s for s in sheets if 'test' in s]
    testsheets.sort()

    #check for correct numbers of files
    if len(basesheets) != len(testsheets):
        return('Error: Unequal number of base and test files')

    for i in range(0, len(basesheets)):
        #make data readable
        base = pd.read_csv(basesheets[i])
        base = base.dropna()
        test = pd.read_csv(testsheets[i])
        test = test.dropna()
        
        #check for data entry mistakes in baseline files
        base_starts = np.where(base.action.str.contains('start'))[0]
        test_starts = np.where(test.action.str.contains('start'))[0]
        base_stops = np.where(base.action.str.contains('stop'))[0]
        test_stops = np.where(test.action.str.contains('stop'))[0]
        
        if even(base_starts)[0] == False:
            return print('File: ', basesheets[i], '. Error(s) at ', even(base_starts)[1])
        if even(test_starts)[0] == False:
            return print('File: ', testsheets[i], '. Error(s) at ', even(test_starts)[1])

        if odd(base_stops)[0] == False:
            return print('File: ', basesheets[i], '. Error(s) at ', odd(base_stops)[1])
        if odd(test_stops)[0] == False:
            return print('File: ', testsheets[i], '. Error(s) at ', odd(test_stops)[1])
        
        if len(base_starts) != len(base_stops):
            return print('Error: unequal number of starts and stop in ', basesheets[i])
        if len(test_starts) != len(test_stops):
            return print('Error: unequal number of starts and stop in ', testsheets[i])
        
        #base.to_csv(basesheets[i], index=False)
        #test.to_csv(testsheets[i], index=False)
        
        t1 = 0; t2 = 0; t3 = 0; t4 = 0
        
        for i in range(0, len(base)):
            if base.action[i] == 'object1_start':
                t1 = t1 + (base.frame[i+1] - base.frame[i])/60
            elif base.action[i] == 'object2_start':
                t2 = t2 + (base.frame[i+1] - base.frame[i])/60
        for i in range(0, len(test)):
            if test.action[i] == 'object1_start':
                t3 = t3 + (test.frame[i+1] - test.frame[i])/60
            elif test.action[i] == 'object2_start':
                t4 = t4 + (test.frame[i+1] - test.frame[i])/60

        DRbase = (t2 - t1)/(t2 + t1)
        DRtest = (t4 - t3)/(t4 + t3)
        #repeat twice
        subid.append(basesheets[i][16:24]); subid.append(basesheets[i][16:24])
        condition.append('base'); condition.append('test')
        DR.append(DRbase); DR.append(DRtest)
    overall['subid'] = subid
    overall['condition'] = condition
    overall['DR'] = DR
    return(overall)
        

graphdata(folder)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-248-2f39b38851ab> in <module>
#      79
#      80
# ---> 81 graphdata(folder)
#
# <ipython-input-248-2f39b38851ab> in graphdata(folder)
#      70         DRtest = (t4 - t3)/(t4 + t3)
#      71         #repeat twice
# ---> 72         subid.append(basesheets[i][16:24]); subid.append(basesheets[i][16:24])
#      73         condition.append('base'); condition.append('test')
#      74         DR.append(DRbase); DR.append(DRtest)
#
# IndexError: list index out of range

# %%
subid = []
condition = []
for i in range(0, len(basevids)):
    subid.append(basevids[i][16:24]); subid.append(basevids[i][16:24])
    condition.append('base'); condition.append('test')
    
overall['subid'] = subid
overall['condition'] = condition

overall
# Out:
#        subid condition
# 0   group1_A      base
# 1   group1_A      test
# 2   group1_B      base
# 3   group1_B      test
# 4   group1_C      base
# 5   group1_C      test
# 6   group2_A      base
# 7   group2_A      test
# 8   group2_B      base
# 9   group2_B      test
# 10  group2_C      base
# 11  group2_C      test
# 12  group3_A      base
# 13  group3_A      test
# 14  group3_B      base
# 15  group3_B      test
# 16  group3_C      base
# 17  group3_C      test
# 18  group3_D      base
# 19  group3_D      test
# 20  group4_A      base
# 21  group4_A      test
# 22  group8_A      base
# 23  group8_A      test
# 24  group8_B      base
# 25  group8_B      test
# 26  group8_C      base
# 27  group8_C      test
# 28  group8_D      base
# 29  group8_D      test
# 30  group9_A      base
# 31  group9_A      test
# 32  group9_B      base
# 33  group9_B      test

# %%
import pandas as pd
group9Bbase = pd.read_csv("cohort1_scoring/1N_OLbase-07222022160116.csv")
group9Btest = pd.read_csv("cohort1_scoring/1N_OLtest-07222022171021.csv")


group9Bbase = group9Bbase.dropna()
group9Bbase = group9Bbase.reset_index(drop=True)
group9Btest = group9Btest.dropna()
group9Btest = group9Btest.reset_index(drop=True)

time1 = 0
time2 = 0
time3 = 0
time4 = 0

for i in range(0, len(group9Bbase)):
    if group9Bbase.action[i] == 'object1_start':
        time1 = time1 + (group9Bbase.frame[i+1] - group9Bbase.frame[i])/60
    elif group9Bbase.action[i] == 'object2_start':
        time2 = time2 + (group9Bbase.frame[i+1] - group9Bbase.frame[i])/60

for i in range(0, len(group9Btest)):
    if group9Btest.action[i] == 'object1_start':
        time3 = time3 + (group9Btest.frame[i+1] - group9Btest.frame[i])/60
    elif group9Btest.action[i] == 'object2_start':
        time4 = time4 + (group9Btest.frame[i+1] - group9Btest.frame[i])/60
        
print(time1, time2, time3, time4)

DIbase = (time2 - time1)/(time2+time1)
DItest = (time4 - time3)/(time4+time3)

print(DIbase, DItest)
# Out:
# 74.25 91.28333333333332 29.499999999999993 40.7
# 0.10289971808296408 0.1595441595441597

# %%
group9Bbase = pd.read_csv("cohort1_scoring/1N_OLbase-07222022160116.csv")
group9Btest = pd.read_csv("cohort1_scoring/1N_OLtest-07222022171021.csv")




group9Bbase
# Out:
#                                                   file    frame         action
# 0    //10.253.5.16/sn data server 3/ryan_morton/obj...   2266.0  object1_start
# 1    //10.253.5.16/sn data server 3/ryan_morton/obj...   2330.0   object1_stop
# 2    //10.253.5.16/sn data server 3/ryan_morton/obj...   2573.0  object2_start
# 3    //10.253.5.16/sn data server 3/ryan_morton/obj...   2631.0   object2_stop
# 4    //10.253.5.16/sn data server 3/ryan_morton/obj...   3041.0  object1_start
# ..                                                 ...      ...            ...
# 263  //10.253.5.16/sn data server 3/ryan_morton/obj...  42021.0   object2_stop
# 264  //10.253.5.16/sn data server 3/ryan_morton/obj...  42267.0  object2_start
# 265  //10.253.5.16/sn data server 3/ryan_morton/obj...  42310.0   object2_stop
# 266  //10.253.5.16/sn data server 3/ryan_morton/obj...  42339.0  object1_start
# 267  //10.253.5.16/sn data server 3/ryan_morton/obj...  42349.0   object1_stop
#
# [268 rows x 3 columns]
